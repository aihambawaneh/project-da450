# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 8
IMAGE_SIZE = 128
CHANNELS=3
EPOCHS=50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 20638 files belonging to 15 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Pepper__bell___Bacterial_spot',
#  'Pepper__bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Tomato_Bacterial_spot',
#  'Tomato_Early_blight',
#  'Tomato_Late_blight',
#  'Tomato_Leaf_Mold',
#  'Tomato_Septoria_leaf_spot',
#  'Tomato_Spider_mites_Two_spotted_spider_mite',
#  'Tomato__Target_Spot',
#  'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  'Tomato__Tomato_mosaic_virus',
#  'Tomato_healthy']

# %%
len(class_names)
# Out:
# 15

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (8, 128, 128, 3)
# [12  9 14  6  1  0 11  4]

# %%
plt.figure(figsize=(20, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(8):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
len(dataset)
# Out:
# 2580

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 2064

# %%
len(val_ds)
# Out:
# 258

# %% [markdown]
# Cache, Shuffle, and Prefetch the Dataset

# %%
train_ds = train_ds.prefetch(1)
val_ds   = val_ds.prefetch(1)
test_ds  = test_ds.prefetch(1)

# %% [markdown]
# Building the Model

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

# %%
n_classes = 15

model = models.Sequential([
    layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),  
    layers.Rescaling(1./255), 

    layers.Conv2D(32, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(), 

    layers.Conv2D(64, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),    
    
    layers.Conv2D(128, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),

    layers.Conv2D(256, 3, padding="same", activation="relu"),
    layers.GlobalAveragePooling2D(),

    layers.Dense(n_classes, activation="softmax"),
])


model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 15)             │         3,855 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 392,271 (1.50 MB)
#  Trainable params: 392,271 (1.50 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=50,
)
# Out:
# Epoch 1/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 99s 41ms/step - accuracy: 0.7753 - loss: 0.6605 - val_accuracy: 0.7108 - val_loss: 0.8238
# Epoch 2/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 84s 39ms/step - accuracy: 0.8267 - loss: 0.5111 - val_accuracy: 0.8275 - val_loss: 0.4840
# Epoch 3/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 77s 36ms/step - accuracy: 0.8650 - loss: 0.4069 - val_accuracy: 0.8797 - val_loss: 0.3548
# Epoch 4/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 78s 36ms/step - accuracy: 0.8899 - loss: 0.3286 - val_accuracy: 0.9079 - val_loss: 0.2834
# Epoch 5/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9070 - loss: 0.2763 - val_accuracy: 0.9419 - val_loss: 0.1958
# Epoch 6/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9187 - loss: 0.2398 - val_accuracy: 0.9050 - val_loss: 0.2935
# Epoch 7/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9319 - loss: 0.2032 - val_accuracy: 0.9399 - val_loss: 0.1751
# Epoch 8/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9388 - loss: 0.1828 - val_accuracy: 0.9399 - val_loss: 0.1761
# Epoch 9/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9414 - loss: 0.1679 - val_accuracy: 0.9656 - val_loss: 0.1029
# Epoch 10/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9469 - loss: 0.1518 - val_accuracy: 0.9787 - val_loss: 0.0693
# Epoch 11/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9545 - loss: 0.1324 - val_accuracy: 0.9569 - val_loss: 0.1201
# Epoch 12/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 97s 45ms/step - accuracy: 0.9557 - loss: 0.1290 - val_accuracy: 0.9743 - val_loss: 0.0840
# Epoch 13/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 35ms/step - accuracy: 0.9621 - loss: 0.1109 - val_accuracy: 0.9486 - val_loss: 0.1492
# Epoch 14/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 78s 36ms/step - accuracy: 0.9621 - loss: 0.1110 - val_accuracy: 0.9283 - val_loss: 0.2110
# Epoch 15/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 82s 38ms/step - accuracy: 0.9710 - loss: 0.0857 - val_accuracy: 0.9462 - val_loss: 0.1529
# Epoch 16/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 79s 37ms/step - accuracy: 0.9643 - loss: 0.1036 - val_accuracy: 0.9685 - val_loss: 0.0963
# Epoch 17/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 75s 35ms/step - accuracy: 0.9729 - loss: 0.0782 - val_accuracy: 0.9753 - val_loss: 0.0724
# Epoch 18/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 75s 35ms/step - accuracy: 0.9756 - loss: 0.0761 - val_accuracy: 0.9491 - val_loss: 0.1734
# Epoch 19/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9701 - loss: 0.0862 - val_accuracy: 0.9661 - val_loss: 0.0927
# Epoch 20/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 77s 36ms/step - accuracy: 0.9761 - loss: 0.0696 - val_accuracy: 0.9801 - val_loss: 0.0690
# Epoch 21/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9803 - loss: 0.0639 - val_accuracy: 0.9574 - val_loss: 0.1148
# Epoch 22/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9780 - loss: 0.0659 - val_accuracy: 0.9792 - val_loss: 0.0610
# Epoch 23/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9813 - loss: 0.0553 - val_accuracy: 0.9811 - val_loss: 0.0466
# Epoch 24/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9809 - loss: 0.0603 - val_accuracy: 0.9869 - val_loss: 0.0450
# Epoch 25/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9831 - loss: 0.0524 - val_accuracy: 0.9971 - val_loss: 0.0147
# Epoch 26/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9826 - loss: 0.0571 - val_accuracy: 0.9714 - val_loss: 0.0928
# Epoch 27/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9855 - loss: 0.0467 - val_accuracy: 0.9830 - val_loss: 0.0449
# Epoch 28/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9848 - loss: 0.0478 - val_accuracy: 0.9888 - val_loss: 0.0307
# Epoch 29/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 35ms/step - accuracy: 0.9868 - loss: 0.0396 - val_accuracy: 0.9922 - val_loss: 0.0214
# Epoch 30/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 76s 35ms/step - accuracy: 0.9841 - loss: 0.0471 - val_accuracy: 0.9913 - val_loss: 0.0194
# Epoch 31/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9867 - loss: 0.0419 - val_accuracy: 0.9845 - val_loss: 0.0493
# Epoch 32/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9855 - loss: 0.0472 - val_accuracy: 0.9651 - val_loss: 0.1190
# Epoch 33/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9892 - loss: 0.0355 - val_accuracy: 0.9927 - val_loss: 0.0195
# Epoch 34/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9880 - loss: 0.0414 - val_accuracy: 0.9806 - val_loss: 0.0548
# Epoch 35/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9899 - loss: 0.0360 - val_accuracy: 0.9981 - val_loss: 0.0067
# Epoch 36/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9900 - loss: 0.0331 - val_accuracy: 0.9903 - val_loss: 0.0430
# Epoch 37/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9897 - loss: 0.0353 - val_accuracy: 0.9976 - val_loss: 0.0071
# Epoch 38/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9915 - loss: 0.0295 - val_accuracy: 0.9927 - val_loss: 0.0201
# Epoch 39/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9895 - loss: 0.0325 - val_accuracy: 0.9893 - val_loss: 0.0283
# Epoch 40/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9894 - loss: 0.0354 - val_accuracy: 0.9787 - val_loss: 0.0745
# Epoch 41/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9901 - loss: 0.0327 - val_accuracy: 0.9758 - val_loss: 0.0958
# Epoch 42/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9901 - loss: 0.0338 - val_accuracy: 0.9995 - val_loss: 0.0029
# Epoch 43/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9922 - loss: 0.0277 - val_accuracy: 0.9796 - val_loss: 0.0538
# Epoch 44/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9921 - loss: 0.0278 - val_accuracy: 0.9918 - val_loss: 0.0227
# Epoch 45/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9895 - loss: 0.0335 - val_accuracy: 0.9966 - val_loss: 0.0104
# Epoch 46/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9931 - loss: 0.0225 - val_accuracy: 0.9976 - val_loss: 0.0096
# Epoch 47/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 75s 35ms/step - accuracy: 0.9896 - loss: 0.0360 - val_accuracy: 0.9840 - val_loss: 0.0408
# Epoch 48/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 74s 34ms/step - accuracy: 0.9918 - loss: 0.0305 - val_accuracy: 0.9840 - val_loss: 0.0540
# Epoch 49/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9947 - loss: 0.0225 - val_accuracy: 0.9981 - val_loss: 0.0081
# Epoch 50/50
# 2064/2064 ━━━━━━━━━━━━━━━━━━━━ 73s 34ms/step - accuracy: 0.9925 - loss: 0.0278 - val_accuracy: 0.9942 - val_loss: 0.0105

# %%
scores = model.evaluate(test_ds)
# Out:
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9976 - loss: 0.0072

# %%
scores
# Out:
# [0.007170111872255802, 0.9975751638412476]

# %% [markdown]
# Plotting the Accuracy and Loss Curves

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 plt.figure(figsize=(8, 8))
#       2 plt.subplot(1, 2, 1)
# ----> 3 plt.plot(range(EPOCHS), acc, label='Training Accuracy')
#       4 plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
#       5 plt.legend(loc='lower right')
#
# NameError: name 'acc' is not defined

# %% [markdown]
# Run prediction on a sample image

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Tomato_Leaf_Mold
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# predicted label: Tomato_Leaf_Mold

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * np.max(predictions[0]), 2)

    return predicted_class, confidence

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 predicted_class, confidence = predict(model, img)
#       3 print(f"Predicted class: {predicted_class}")
#       4 print(f"Confidence: {confidence}%")
#
# NameError: name 'model' is not defined

# %%
import os
save_dir = "../models"
os.makedirs(save_dir, exist_ok=True)
existing = [
    int(f.split(".")[0]) 
    for f in os.listdir(save_dir) 
    if f.endswith(".keras") and f.split(".")[0].isdigit()
]
model_version = max(existing + [0]) + 1
model.save(f"{save_dir}/{model_version}.keras")
print(f"Model saved at version {model_version}")
# Out:
# Model saved at version 1
