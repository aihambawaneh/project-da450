# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# c:\Users\USER\miniconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
BATCH_SIZE = 15
IMAGE_SIZE = 128
CHANNELS=3
EPOCHS=50

# %%
# 1. تحميل المجموعات الثلاث
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "C:\\Users\\USER\\Desktop\\450data\\PlantVillage_Split\\train",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 14440 files belonging to 15 classes.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "C:\\Users\\USER\\Desktop\\450data\\PlantVillage_Split\\val",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 2061 files belonging to 15 classes.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "C:\\Users\\USER\\Desktop\\450data\\PlantVillage_Split\\test",
    seed=123,
    shuffle=False, # لا نحتاج للخلط في التست
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 4137 files belonging to 15 classes.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Pepper__bell___Bacterial_spot',
#  'Pepper__bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Tomato_Bacterial_spot',
#  'Tomato_Early_blight',
#  'Tomato_Late_blight',
#  'Tomato_Leaf_Mold',
#  'Tomato_Septoria_leaf_spot',
#  'Tomato_Spider_mites_Two_spotted_spider_mite',
#  'Tomato__Target_Spot',
#  'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  'Tomato__Tomato_mosaic_virus',
#  'Tomato_healthy']

# %%
len(class_names)
# Out:
# 15

# %%
for image_batch, labels_batch in train_ds.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (15, 128, 128, 3)
# [10  8  9  6 12 10  5  9  5  7  7  3 10 14  1]

# %%
plt.figure(figsize=(20, 10))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(15):
        ax = plt.subplot(3, 5, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (963, 138, 276)

# %%
"""
def get_dataset_partitions_tf(ds, train_split=0.7, val_split=0.2, test_split=0.1, shuffle=True, shuffle_size=5000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12, reshuffle_each_iteration=False)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds
"""
# Out:
# '\ndef get_dataset_partitions_tf(ds, train_split=0.7, val_split=0.2, test_split=0.1, shuffle=True, shuffle_size=5000):\n    assert (train_split + test_split + val_split) == 1\n\n    ds_size = len(ds)\n\n    if shuffle:\n        ds = ds.shuffle(shuffle_size, seed=12, reshuffle_each_iteration=False)\n\n    train_size = int(train_split * ds_size)\n    val_size = int(val_split * ds_size)\n\n    train_ds = ds.take(train_size)    \n    val_ds = ds.skip(train_size).take(val_size)\n    test_ds = ds.skip(train_size).skip(val_size)\n\n    return train_ds, val_ds, test_ds\n'

# %%
#train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)
train_ds = train_ds.shuffle(1000, seed=12 ,reshuffle_each_iteration=True)

# %%
len(train_ds)
# Out:
# 963

# %%
len(val_ds)
# Out:
# 138

# %% [markdown]
# Prefetch the Dataset

# %%
train_ds = train_ds.prefetch(1) # for no wating to next batch & and dont change the data value 
val_ds   = val_ds.prefetch(1)
test_ds  = test_ds.prefetch(1)

# %% [markdown]
# Building the Model

# %%
n_classes = 15

model = models.Sequential([
    layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)), 
    layers.Rescaling(1./255), 

    layers.Conv2D(32, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(), 

    layers.Conv2D(64, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),    
    
    layers.Conv2D(128, 3, padding="same", activation="relu"),
    layers.MaxPooling2D(),

    layers.Conv2D(256, 3, padding="same", activation="relu"),
    layers.GlobalAveragePooling2D(), # it wrok as flaten + 128

    layers.Dropout(0.3),

    layers.Dense(n_classes, activation="softmax"),
])

early_stop = EarlyStopping(
    monitor='val_loss',  
    patience=5,              
    restore_best_weights=True
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 15)             │         3,855 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 392,271 (1.50 MB)
#  Trainable params: 392,271 (1.50 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
model.compile(
    optimizer='adam',
    loss=SparseCategoricalCrossentropy(),  
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=50,
    callbacks=[early_stop],
)
# Out:
# Epoch 1/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 86s 78ms/step - accuracy: 0.3787 - loss: 1.8781 - val_accuracy: 0.6181 - val_loss: 1.1523
# Epoch 2/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 75s 75ms/step - accuracy: 0.6731 - loss: 0.9787 - val_accuracy: 0.7749 - val_loss: 0.6688
# Epoch 3/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 75s 76ms/step - accuracy: 0.7497 - loss: 0.7448 - val_accuracy: 0.8074 - val_loss: 0.5707
# Epoch 4/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.7830 - loss: 0.6383 - val_accuracy: 0.8627 - val_loss: 0.4247
# Epoch 5/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.8280 - loss: 0.5172 - val_accuracy: 0.8928 - val_loss: 0.3290
# Epoch 6/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.8425 - loss: 0.4651 - val_accuracy: 0.8641 - val_loss: 0.3884
# Epoch 7/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.8675 - loss: 0.3923 - val_accuracy: 0.8525 - val_loss: 0.4671
# Epoch 8/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 75ms/step - accuracy: 0.8829 - loss: 0.3454 - val_accuracy: 0.9044 - val_loss: 0.2742
# Epoch 9/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.8963 - loss: 0.3082 - val_accuracy: 0.9020 - val_loss: 0.2731
# Epoch 10/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9057 - loss: 0.2760 - val_accuracy: 0.9335 - val_loss: 0.1984
# Epoch 11/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9179 - loss: 0.2438 - val_accuracy: 0.9345 - val_loss: 0.2059
# Epoch 12/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9224 - loss: 0.2331 - val_accuracy: 0.9457 - val_loss: 0.1735
# Epoch 13/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9323 - loss: 0.2019 - val_accuracy: 0.9301 - val_loss: 0.1948
# Epoch 14/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 76s 76ms/step - accuracy: 0.9352 - loss: 0.1885 - val_accuracy: 0.9491 - val_loss: 0.1431
# Epoch 15/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9394 - loss: 0.1752 - val_accuracy: 0.9282 - val_loss: 0.2208
# Epoch 16/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9412 - loss: 0.1732 - val_accuracy: 0.9622 - val_loss: 0.1131
# Epoch 17/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 75s 75ms/step - accuracy: 0.9466 - loss: 0.1600 - val_accuracy: 0.9525 - val_loss: 0.1498
# Epoch 18/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 75s 75ms/step - accuracy: 0.9479 - loss: 0.1505 - val_accuracy: 0.9457 - val_loss: 0.1674
# Epoch 19/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 77s 77ms/step - accuracy: 0.9522 - loss: 0.1381 - val_accuracy: 0.9529 - val_loss: 0.1378
# Epoch 20/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 73s 74ms/step - accuracy: 0.9524 - loss: 0.1376 - val_accuracy: 0.9578 - val_loss: 0.1318
# Epoch 21/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9589 - loss: 0.1230 - val_accuracy: 0.9709 - val_loss: 0.0938
# Epoch 22/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9608 - loss: 0.1166 - val_accuracy: 0.9588 - val_loss: 0.1231
# Epoch 23/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 73s 73ms/step - accuracy: 0.9669 - loss: 0.0989 - val_accuracy: 0.9592 - val_loss: 0.1160
# Epoch 24/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 73s 74ms/step - accuracy: 0.9627 - loss: 0.1114 - val_accuracy: 0.9757 - val_loss: 0.0768
# Epoch 25/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9675 - loss: 0.0983 - val_accuracy: 0.9733 - val_loss: 0.0793
# Epoch 26/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9679 - loss: 0.0965 - val_accuracy: 0.9689 - val_loss: 0.0885
# Epoch 27/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 73s 74ms/step - accuracy: 0.9702 - loss: 0.0882 - val_accuracy: 0.9573 - val_loss: 0.1042
# Epoch 28/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 73s 74ms/step - accuracy: 0.9684 - loss: 0.0936 - val_accuracy: 0.9199 - val_loss: 0.2458
# Epoch 29/50
# 963/963 ━━━━━━━━━━━━━━━━━━━━ 74s 74ms/step - accuracy: 0.9720 - loss: 0.0816 - val_accuracy: 0.9748 - val_loss: 0.0817

# %%
scores = model.evaluate(test_ds)
# Out:
# 276/276 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.9703 - loss: 0.0843

# %%
scores
# Out:
# [0.0843060314655304, 0.9702683091163635]

# %% [markdown]
# Plotting the Accuracy and Loss Curves

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
EPOCHS= 29
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Run prediction on a sample image

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Pepper__bell___Bacterial_spot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# predicted label: Pepper__bell___Bacterial_spot

# %%
import os

save_dir = r"C:\\Users\\USER\\Desktop\\450data\\model" 

# إنشاء المجلد إذا لم يكن موجوداً
os.makedirs(save_dir, exist_ok=True)

existing = [
    int(f.split(".")[0]) 
    for f in os.listdir(save_dir) 
    if f.endswith(".keras") and f.split(".")[0].isdigit()
]

model_version = max(existing + [0]) + 1

full_save_path = os.path.join(save_dir, f"{model_version}.keras")

model.save(full_save_path)

print(f"Model saved successfully!")
print(f"Location: {full_save_path}")
# Out:
# Model saved successfully!
# Location: C:\\Users\\USER\\Desktop\\450data\\model\2.keras

# %%
import os
import tensorflow as tf

# حدد المجلد الذي وضعت فيه الموديل
model_path = r"C:\\Users\\USER\\Desktop\\450data\\model\\2.keras" 

if os.path.exists(model_path):
    model = tf.keras.models.load_model(model_path)
    print("تم تحميل الموديل بنجاح")
else:
    print("الملف غير موجود في المسار المحدد!")
# Out:
# تم تحميل الموديل بنجاح

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * np.max(predictions[0]), 2)

    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
